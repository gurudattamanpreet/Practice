# %% [markdown]
# <a href="https://colab.research.google.com/github/gurudattamanpreet/Practice/blob/main/String_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Declare a string and store it in a variable.
a='This is python class'
#Check the type and print the id of the same.
print('String is: ', a, '\n', 'Id of the variable is:',id(a), '\n','Data type of the variable is:', type(a))
# Out:
# String is:  This is python class
#  Id of the variable is: 134520658832048
#  Data type of the variable is: <class 'str'>

# %%
#Which are valid/invalid strings
1. 'This is Python class'
valid

2. "This is Python class"
valid

3. '''This is Python class'''
valid

4. """This is Python class"""
valid

5. 'This is Python's class'
invalid
#the correct way of writing this is:
"This is python's  class"


6. "We provides "Java", "Python" classes"
invalid
#the correct way of writing this is:
"We provides 'Java', 'Python' classes"


7. "We provides 'Java', 'Python' classes"
valid

8. "This is Python's class"
valid

9. """We provides "Java", "Python" classes"""
valid

10. '''We provides "Java", "Python" classes'''
valid

11. '''We provides
"Java", "Python"
classes'''
valid

12. 'This is
Python
class'
invalid
#the correct way of writing this is:
'''We provides
"Java", "Python"
classes'''
# Out:
#   File "<ipython-input-1-6da3cfec693c>", line 14
#     5. 'This is Python's class'
#                               ^
# SyntaxError: unterminated string literal (detected at line 14)

# %%
#Write the code to get the output mentioned below print statement
my_str = "Although that way may not be obvious at first unless you're Dutch."
my_str1 = "Although that way may not be obvious at first unless you're Dutch."



print(f'The length of my_str is {len(my_str)}')
#output:- The length of my_str is 66

print(f'id of my_str and my_str1 is same? - {id(my_str)==id(my_str1)}')
#output:- id of my_str and my_str1 is same? - True/False

print(f'Type of my_str is: {type(my_str)}')
#output:- Type of my_str is: str
# Out:
# The length of my_str is 66
# id of my_str and my_str1 is same? - False
# Type of my_str is: <class 'str'>

# %%
#Indexing
my_str = "Although 8 that way may not be obvious at first unless you're Dutch"
#Write the code to get the output,instructions are mentioned below print statement. use indexing
print(f'The first character in my_str is: {my_str[0]}')
#output:- The first character in my_str is: A
#Note:- Use positive indexing

p=len(my_str)
print(f'The first character in my_str is: {my_str[-p]}')

#output:- The first character in my_str is: h
#Note:- Use len() function.

print(f'The character at index 10 in my_str is: {my_str[10]}')
#output:- The character at index 10 in my_str is: ' '
#Note:- Use positive indexing

print(f'The last character in my_str is: {my_str[-1]} ')
#output:- The last character in my_str is: h
#Note:- Use negative indexing.

print(f'The last character in my_str is: {my_str[(p-1)]}')
#output:- The last character in my_str is: h
#Note:- Use len() function.

#doubt:
print(f'The total character in my_str is: {len(my_str)}')
#output:- The character in my_str is: 8
#Note:- Use positive index
# Out:
# The first character in my_str is: A
# The first character in my_str is: A
# The character at index 10 in my_str is:
# The last character in my_str is: h
# The last character in my_str is: h
# The total character in my_str is: 67

# %%
#Slicing
my_str = "Although that way may not be obvious at first unless you're Dutch."
#Write the code to get the output,instructions are mentioned below print statement. use slicing
print(my_str[::])
#output:- You have sliced: Although that way may not be obvious at first unless you're Dutch.Without begin, end and step


print(my_str[0:len(my_str)])
#output:- You have sliced: Although that way may not be obvious at first unless you're Dutch.with begin as 0 end using len and without step


print(my_str[::1])
#output:- You have sliced: Although that way may not be obvious at first unless you're Dutch.without begin and end but using step


print(my_str[0:67:1])
#output:- You have sliced: Although that way may not be obvious at first unless you're Dutch.With begin, end and step


print(my_str[0:0:-1])
#output:- You have sliced:   .with using begin and end using postive values and step as negative values.
#Slicing command should print empty string.


print(my_str[::2])
#output:- You have sliced: Atog htwymyntb biu tfrtuls o'eDth


print(my_str[::3])
#output:- You have sliced: Ahgttam tebo  r lsorDc


print(my_str[::-1])
#output:- You have sliced: .hctuD er'uoy sselnu tsrif ta suoivbo eb ton yam yaw taht hguohtlA. Use only step


print(my_str[-1:-67:-1])
#output:- You have sliced: .hctuD er'uoy sselnu tsrif ta suoivbo eb ton yam yaw taht hguohtlA. Use begin end and step.


print(my_str[::-2])
#output:- You have sliced: .cu ruysen si asovoe o a a athuhl. use only step


print(my_str[-1:-67:-2])
#output:- You have sliced: .cu ruysen si asovoe o a a athuhl. use begin, end and step.


print(my_str[10:17:-1])
#What will be the output?
#empty


print(my_str[-49:-56:-1])
#output:- You have sliced: yaw ta, Using begin, end and step.

print(my_str[49:56:1])
#output:- You have sliced: ess you. Using begin, end and step.
# Out:
# Although that way may not be obvious at first unless you're Dutch.
# Although that way may not be obvious at first unless you're Dutch.
# Although that way may not be obvious at first unless you're Dutch.
# Although that way may not be obvious at first unless you're Dutch.
#
# Atog htwymyntb biu tfrtuls o'eDth
# Ahgttam tebo  r lsorDc
# .hctuD er'uoy sselnu tsrif ta suoivbo eb ton yam yaw taht hguohtlA
# .hctuD er'uoy sselnu tsrif ta suoivbo eb ton yam yaw taht hguohtlA
# .cu ruysen si asovoe o a a athuhl
# .cu ruysen si asovoe o a a athuhl
#
#  yaw ta
# ess you

# %%
#Basic operation on string
str1 = 'Learning'
str2 = 'Python'

#Write the code to get the output,instructions are mentioned below.
#Output is: Learning Python

print(str1+ ' ' + str2)

#Find below Output
#Output is: LearningLearningLearning

print(str1*3)
# Out:
# Learning Python
# LearningLearningLearning

# %%
#Find below Output
str1 = 'Python'
str2 = 'Python'
str3 = 'Python$'
str4 = 'Python$'

#print True by using identity operator between str1 and str2
print(str1==str2)

#print False by using identity operator between str1 and str3
print(str1==str3)

#print False by using identity operator between str4 and str3
print(str4==str3)

#Check if P is available in str1 and print True by using membership operator


#Check if $ is available in str3 and print True by using membership operator


#Check if N is available in str3 and print False by using membership operator
# Out:
# True
# False
# True

# %%
#Complete the below code
str1 = 'This is Python class'
#write the code to replace 'Python' with 'Java' and you should get below error.
#TypeError: 'str' object does not support item assignment.

str1.replace(['Java'],['Python'])
print(str1,type(str1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-3ebd2d7615d5> in <cell line: 0>()
#       4 #TypeError: 'str' object does not support item assignment.
#       5
# ----> 6 str1.replace(['Java'],['Python'])
#       7 print(str1,type(str1))
#
# TypeError: replace() argument 1 must be str, not list

# %%
str1 = 'A'
str2 = 'A'
#Compare str1 and str2 and print True using comparison operator
str1>str2

#Compare str1 and str2 and print True using equality operator


#Compare str1 and str2 and print False using equality operator


#Compare str1 and str2 and print False using comparison operator
# Out:
# False

# %%
str1 = 'A'
str2 = 'A'
#Compare str1 and str2 and print True using comparison operator
print(str1>=str2)

#Compare str1 and str2 and print True using equality operator
print(str1==str2)

#Compare str1 and str2 and print False using equality operator
print(str1==str2.lower())

#Compare str1 and str2 and print False using comparison operator
print(str1<str2)
# Out:
# True
# True
# False
# False

# %%
str1 = 'A'
str2 = '65'
#Compare str1 and str2 using comparison operator and it should give below error.
#Error: TypeError: '>=' not supported between instances of 'str' and 'int'

print(str1>=int(str2))

#Compare str1 and str2 and print True using equality operator
print(type(str1)==type(str1))

#Compare str1 and str2 and print False using equality operator
print(str1==str2)
# Out:
# True
# False

# %%
str1 = 'Python'
str2 = 'Python'
#Compare str1 and str2 and print True using comparison operator
print(str1>=str2)

#Compare str1 and str2 and print True using equality operator
print(str1==str2)

#Compare str1 and str2 and print False using equality operator
print(str1==str2.lower())

#Compare str1 and str2 and print False using comparison operator
print(str1>str2)
# Out:
# True
# True
# False
# False

# %%
str1 = 'Python'
str2 = 'python'
#Compare str1 and str2 and print True using comparison operator
print(id(str2)>id(str1))

#Compare str1 and str2 and print True using equality operator
print(type(str1)==type(str2))

#Compare str1 and str2 and print False using equality operator
print(str1==str2)

#Compare str1 and str2 and print False using comparison operator
print(str1>str2)
# Out:
# True
# True
# False
# False

# %%
a = 'Python'
b = ''

#Apply logical opereators (and, or & not) on above string values and observe the output.
print(a and b)
print(a or b)
print(b or a )
print(not a)
print(not b)
# Out:
# Python
# Python
# False
# True

# %%
a = ''
b = ''

#Apply logical opereators (and, or & not) on above string values and observe the output.
print(a and b)
print(a or b)
print(b or a)
print(not a)
print(not b)
# Out:
# True
# True

# %%
a = 'Python'
b = 'learning'

#Apply logical opereators (and, or & not) on above string values and observe the output.
print(a and b)
print(a or b)
print(b or a)
print(not a)
print(not b)
# Out:
# learning
# Python
# learning
# False
# False

# %%
my_str = "Although 8 that way may not be obvious at first unless you're Dutch"

#Write the code to get the total count of 't' in above string. Use find() and index() method.
print()
print()

#Write the code to get the index of '8' in my_str. Use find() and index() method.
print(my_str.find('8'))


#What will be the output of below code?
print(my_str.find('the'))


# print(my_str.index('the'))
# value error

print(my_str.find('t', 9, 15))


print(my_str.rfind('u'))


print(my_str.rindex('u'))
# Out:
# 9
# -1
# 11
# 63
# 63

# %%
# W A P which applies strip() method if any string, which will be taken from user, starts and ends with space, or applies
#rrstrip() method if that string only ends with space or applies lstrip() method if that string only starts with a space.

a=input('enter a word: ').strip()
print(a)
#For example:-
#input:- '    Python   '
#output:- 'Python'

#input:- '    Python'
#output:- 'Python'

#input:- 'Python   '
#output:- 'Python'
# Out:
# enter a word:               python
#               python

# %%
my_str = "Although 8 that way may not be obvious at first unless you're Dutch"

#Write the code to convert all alphabets in my_str into upper case.
print(my_str.upper())

#Write the code to convert all alphabets in my_str into lower case.
print(my_str.lower())

#Write the code to swap the cases of all alphabets in my_str.(lower to upper and upper to lower)
print(my_str.swapcase())
# Out:
# ALTHOUGH 8 THAT WAY MAY NOT BE OBVIOUS AT FIRST UNLESS YOU'RE DUTCH
# although 8 that way may not be obvious at first unless you're dutch
# aLTHOUGH 8 THAT WAY MAY NOT BE OBVIOUS AT FIRST UNLESS YOU'RE dUTCH

# %%
#Write the code which takes one string from user and if it starts with small case letter then convert it to corresponding
#capital letter otherwise if starts with capital letters then convert first character of every word in that string into capital.

a=input('enter a word: ')
a=a.title()
print(a)
# Out:
# enter a word: python
# Python

# %%
#Take a string from user and check if it is:-
#     1. all letters are in lower case
#     2. all letters are in upper case
#     3. in title case

a=input('enter a word: ')
if a == a.lower():
  print('all letters are lowercase')
elif a==a.upper():
    print('all letters are uppercase')
elif a==a.title():
    print('all letters are in title case')
else:
    print('sring doesnot match any of the criteria')
# Out:
# enter a word: Python Is A Programming Language
# all letters are in title case

# %%
#What will be output of below code?
s = chr(65) + chr(97)
print(s.isprintable())

s = chr(27) + chr(97)
print(s.isprintable())

s = '\n'
print(s.isprintable())

s = ''
print(s.isprintable())
# Out:
# True
# False
# False
# True

# %%
#What will be output of below code?
my_string = '  '
print(my_string.isascii())

my_string = 'Studytonight'
print(my_string.isascii())

my_string = 'Study tonight'
print(my_string.isascii())

my_string = 'Studytonight@123'
print(my_string.isascii())

my_string = '°'
print(my_string.isascii())

my_string = 'ö'
print(my_string.isascii())
# Out:
# True
# True
# True
# True
# False
# False

# %%
#What will be the output of below code?
firstString = "der Fluß"
secondString = "der Fluss"

# if firstString.casefold() == secondString.casefold():
#     print('The strings are equal.')
# else:
#     print('The strings are not equal.')

# %%
#Write the code to get below output
#O/P 1:- python** (using ljust method)

a='python'
print(a.ljust(8,'*'))


#Write the code to get below output
#O/P 1:- **python (using rjust method)

a='python'
print(a.rjust(8,'*'))

#Write the code to get below output
#O/P 1:- **python** (using rjust method)
a = 'python'
print(a.center(10,'*'))
# Out:
# python**
# **python
# **python**

# %%
#Write a Python program to find the length of the my_str:-

my_str='python   &   java   are    the   programming   language'
len(my_str)

#Input:- 'Write a Python program to find the length of the my_str'
#Output:- 55
# Out:
# 55

# %%
#Write a Python program to find the total number of times letter 'p' is appeared in the below string:-

a='peter piper picked a peck of pickled peppers.'
a.count('p')

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 9
# Out:
# 9

# %%
#Write a Python Program, to print all the indexes of all occurences of letter 'p' appeared in the string:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:-
# 0
# 6
# 8
# 12
# 21
# 29
# 37
# 39
# 40

a='peter piper picked a peck of pickled peppers.'
for i in range(0,len(a),1):
  if a[i]=='p':
    print(i)
# Out:
# 0
# 6
# 8
# 12
# 21
# 29
# 37
# 39
# 40

# %%
#Write a python program to find below output:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- ['peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers.']

a='peter piper picked a peck of pickled peppers.'
print(a.split())
# Out:
# ['peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers.']

# %%
#Write a python program to find below output:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 'peppers. pickled of peck a picked piper peter'

a='peter piper picked a peck of pickled peppers.'
b=a.split()
print(b[::-1])
# Out:
# ['peppers.', 'pickled', 'of', 'peck', 'a', 'picked', 'piper', 'peter']

# %%
#Write a python program to find below output:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- '.sreppep delkcip fo kcep a dekcip repip retep'

a='peter piper picked a peck of pickled peppers.'
print(a[::-1])
# Out:
# .sreppep delkcip fo kcep a dekcip repip retep

# %%
#Write a python program to find below output:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 'retep repip dekcip a kcep fo delkcip .sreppep'

a='peter piper picked a peck of pickled peppers.'
b=a.split()
c=''
for i in range(0,len(b),1):
  c=b[i][::-1]+ ' '
  print(c,end='')
# Out:
# retep repip dekcip a kcep fo delkcip .sreppep

# %%
#Write a python program to find below output:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 'Peter Piper Picked A Peck Of Pickled Peppers.'

a='peter piper picked a peck of pickled peppers.'
print(a.title())
# Out:
# Peter Piper Picked A Peck Of Pickled Peppers.

# %%
#Write a python program to find below output:-

#Input:- 'Peter Piper Picked A Peck Of Pickled Peppers.'
#Output:- 'Peter piper picked a peck of pickled peppers.'

a='Peter Piper Picked A Peck Of Pickled Peppers.'
print(a.capitalize())
# Out:
# Peter piper picked a peck of pickled peppers.

# %%
#Write a python program to implement index method. If sub_str is found in my_str then it will print the index
# of first occurrence of first character of matching string in my_str:-

#Input:- my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.', sub_str = 'Pickl'
#Output:- 29

my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
print(my_str.index('Pickl'))
# Out:
# 29

# %%
#Write a python program to implement replace method. If sub_str is found in my_str then it will replace the first
#occurrence of sub_str with new_str else it will will print sub_str not found:-

#Input:- my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.', sub_str = 'Peck', new_str = 'Pack'
#Output:- 'Peter Piper Picked A Pack Of Pickled Peppers.'

my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
my_str=my_str.replace('Peck', 'Pack')
print(my_str)
# Out:
# Peter Piper Picked A Pack Of Pickled Peppers.

# %%
#Write a python program to find below output (implements rjust and ljust):-

#Input:- 'Peter Piper Picked A Peck Of Pickled Peppers.', sub_str = 'Peck',
#Output:- '*********************Peck********************'

a='Peter Piper Picked A Peck Of Pickled Peppers.'
print(a.center(80,'*'))
# Out:
# *****************Peter Piper Picked A Peck Of Pickled Peppers.******************
