# %% [markdown]
# <a href="https://colab.research.google.com/github/gurudattamanpreet/Practice/blob/main/sql_in_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from IPython import get_ipython
from IPython.display import display

# !pip install ipython-sql prettytable

# %load_ext sql
# %sql sqlite://

# %config SqlMagic.style = 'DEFAULT'

# !pip install ipython-sql
# !pip install prettytable==2.5.0

# %%
# %%sql
# CREATE TABLE students (
#     name TEXT,
#     age INTEGER,
#     grade TEXT,
#     city TEXT,
#     enrolled BOOLEAN
# );
#
# INSERT INTO students (name, age, grade, city, enrolled) VALUES
# ('Ravi', 20, 'A', 'Delhi', 1),
# ('Geeta', 21, 'B', 'Mumbai', 1),
# ('Amit', 22, 'C', 'Pune', 0),
# ('Neha', 23, 'A', 'Delhi', 1),
# ('Raj', 24, 'B', 'Chennai', 0);
# Out:
#  * sqlite://
# Done.
# 5 rows affected.
# []

# %%
result = %sql SELECT * FROM students
# Out:
#  * sqlite://
# Done.

# %%
df = result.DataFrame()

# %%
df
# Out:
#     name  age grade     city  enrolled
# 0   Ravi   20     A    Delhi         1
# 1  Geeta   21     B   Mumbai         1
# 2   Amit   22     C     Pune         0
# 3   Neha   23     A    Delhi         1
# 4    Raj   24     B  Chennai         0
