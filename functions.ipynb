# %% [markdown]
# <a href="https://colab.research.google.com/github/gurudattamanpreet/Practice/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class student:
  def __init__(self):
    self.name='manpreet'
    self.subject='science'
    self.roll_num=123

# %%
s1=student()

# %%
s1.name
# Out:
# 'manpreet'

# %%
s1.roll_num
# Out:
# 123

# %%
s1.subject
# Out:
# 'science'

# %%
def student2(self):
  self.name='manpreet'
  self.subject='science'
  self.roll_num=321

# %%
s2=student2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11947/3594746984.py in <cell line: 0>()
# ----> 1 s2=student2()
#
# TypeError: student2() missing 1 required positional argument: 'self'
