# %% [markdown]
# <a href="https://colab.research.google.com/github/gurudattamanpreet/Practice/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class student:
  def __init__(self):
    self.name='manpreet'
    self.subject='science'
    self.roll_num=123

# %%
s1=student()

# %%
s1.name
# Out:
# 'manpreet'

# %%
s1.roll_num
# Out:
# 123

# %%
s1.subject
# Out:
# 'science'

# %%
class student2:
  def __init__(self,name,subject,roll_num):
   self.name=name
   self.roll_num=roll_num
   self.subject=subject

# %%
s2=student2('kamaljeet','science',321)

# %%
s2.name
# Out:
# 'kamaljeet'

# %%
s2.roll_num
# Out:
# 321

# %%
s2.subject
# Out:
# 'science'

# %%
def student3(self):
  self.name='manpreet'
  self.subject='science'
  self.roll_num=321

# %%
s3=student3()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11947/241994445.py in <cell line: 0>()
# ----> 1 s3=student3()
#
# TypeError: student3() missing 1 required positional argument: 'self'

# %%
def student4(self,name,roll_num,subject):
  self.name=name
  self.roll_num=roll_num
  self.subject=subject

# %%
s4=student4('kamaljeet',123,'science')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11947/3407118415.py in <cell line: 0>()
# ----> 1 s4=student4('kamaljeet',123,'science')
#
# TypeError: student4() missing 1 required positional argument: 'subject'
