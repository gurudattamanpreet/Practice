# %% [markdown]
# <a href="https://colab.research.google.com/github/gurudattamanpreet/Practice/blob/main/Python_Test_GT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ek string ka first letter capital karo.
a='python is a programming language'
print(a.capitalize())
# Out:
# Python is a programming language

# %%
# Ek string ko lowercase me convert karo using .casefold().
a='PYTHON IS PROGRAMMING LANGUAGE'
print(a.casefold())
# Out:
# python is programming language

# %%
# String ko 20 width ke beech center karo using *.
a='python'
print(a.center(20,'*'))
# Out:
# *******python*******

# %%
# String me kisi word ki occurrence count karo.
a='python is a programming language python'
print(a.count('python'))
# Out:
# 2

# %%
# String ko UTF-8 me encode karo.
a='python is a programming language python'
print(a.encode())
# Out:
# b'python is a programming language python'

# %%
# Check karo string kisi word se end hoti hai ya nahi.
a='python is a programming language python2'
if a[-1].isalpha():
  print('ends with word')
else:
  print('ends with something else')
# Out:
# ends with something else

# %%
# String me \t ho to use space me badlo using .expandtabs().
a='python is a programming \t language python'
print(a.expandtabs())
# Out:
# python is a programming          language python

# %%
# “java” ka index dhoondo string me.
a='python is a programming language java'
print(a.index('java'))
# Out:
# 33

# %%
# {} ke andar koi word daalo using .format()
a='python'
b='java'
print(f'{a} & {b} are programming language')
# Out:
# python & java are programming language

# %%
# Ek dictionary ke help se .format_map() ka use karo string formatting me.

# %%
# “hello world” me 'o' ka index nikaalo using .find().
a='hello world'
a.find('o')
# Out:
# 4

# %%
# Check karo string alphanumeric hai ya nahi.
a='python3 is a  programming language python'
b=''.join(a.split())
print(b.isalnum())
# Out:
# True

# %%
# Check karo string sirf alphabets ka bana hai ya nahi.
a='python is a  programming language python'
b=' '.join(a.split())
print(b.isalpha())
# Out:
# False

# %%
# Check karo string ASCII characters ka hai ya nahi.
a='python is a  programming language python'
print(a.isascii())
# Out:
# True

# %%
# Check karo string decimal numbers ka bana hai ya nahi.
a='22'
print(a.isdecimal())
# Out:
# True

# %%
# Check karo string digits ka bana hai ya nahi.
a='23'
print(a.isdigit())
# Out:
# True

# %%
# Check karo string ek valid identifier hai ya nahi.
a='for'
a.isidentifier()
# Out:
# True

# %%
# Check karo string lowercase me hai ya nahi.
a='python is a  programming language python'
print(a.islower())
# Out:
# True

# %%
# Check karo string numeric hai ya nahi.
a='python is a  programming language python'
print(a.isnumeric())
# Out:
# False

# %%
# Check karo string printable hai ya nahi.
a='python is a  programming language python'
print(a.isprintable())
# Out:
# True

# %%
# Check karo string sirf spaces ka bana hai ya nahi.
a='python is a  programming language python'
print(a.isspace())
# Out:
# False

# %%
# Check karo string title case me hai ya nahi.
a='python is a  programming language python'
print(a.istitle())
# Out:
# False

# %%
# Ek list of words ko string me jodo using .join().
a=['python', 'is', 'a',  'programming', 'language', 'python']
''.join(a)
# Out:
# 'pythonisaprogramminglanguagepython'

# %%
# Ek string me se prefix remove karo using .removeprefix().
a='abc@gmailcom'
print(a.removeprefix('abc'))
# Out:
# @gmailcom

# %%
# Ek string me se suffix remove karo using .removesuffix().
a='abc@gmail.com'
print(a.removesuffix('.com'))
# Out:
# abc@gmail
