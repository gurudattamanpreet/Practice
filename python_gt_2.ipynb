# %% [markdown]
# <a href="https://colab.research.google.com/github/gurudattamanpreet/Practice/blob/main/python_gt_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ek string ka first letter capital karo.
a='python is a programming language'
a.capitalize()
# Out:
# 'Python is a programming language'

# %%
# Ek string ko lowercase me convert karo using .casefold().
a='PYTHON IS A PROGRAMMING LANGUAGE'
a.casefold()
# Out:
# 'python is a programming language'

# %%
# String ko 20 width ke beech center karo using *.
a='pyhton'
a.center(20,'*')
# Out:
# '*******pyhton*******'

# %%
# String me kisi word ki occurrence count karo.
a='python is a programming language python'
a.count('python')Check karo string kisi word se end hoti hai ya nahi.
# Out:
# 2

# %%
# String ko UTF-8 me encode karo.
a='python is a programming language python'
b=a.encode('utf-8')
print(b,type(b))
b.decode('utf-8')
# Out:
# b'python is a programming language python' <class 'bytes'>
# 'python is a programming language python'

# %%
# Check karo string kisi word se end hoti hai ya nahi.
a='python is a programming language python'
a.endswith('python')
# Out:
# True

# %%
# String me \t ho to use space me badlo using .expandtabs().
a='python is a programming \t language python'
a.expandtabs()
# Out:
# 'python is a programming          language python'

# %%
# “java” ka index dhoondo string me.
a='python is a java programming language python'
a.index('java')
# Out:
# 12

# %%
# Ek empty list banao aur usme “Python” add karo.
a=[]
a.extend(['python','java'])
print(a)
# Out:
# ['python', 'java']

# %%
# Ek list clear karo using .clear().
a=['python','java',23,65,87,'php']
a.clear()
print(a)
# Out:
# []

# %%
# Ek list ko copy karo, fir dono list ka id compare karo.
a=['python','java',23,65,87,'php']
b=a.copy()
print(id(a))
print(id(b))
# Out:
# 138757311991872
# 138757311993088

# %%
# Ek list me “python” kitni baar aaya, count karo.
a=['python','java',23,65,87,'php','python']
a.count('python')
# Out:
# 2

# %%
# Ek list me ek aur list merge karo using .extend().
a=['python','java',23,65,87,'php','python']
b=['python','net',23,65,87,'java','python']
c=['python','java',23,65,87,'php','python']
a.extend(b)
a.extend(c)
print(a)
# Out:
# ['python', 'java', 23, 65, 87, 'php', 'python', 'python', 'net', 23, 65, 87, 'java', 'python', 'python', 'java', 23, 65, 87, 'php', 'python']

# %%
# Ek list me “java” ka index find karo.
a=['python','java',23,65,87,'php','java','python']
a.index('java',2)
# agar dekhana ho ki index 1 k baad bhi java h to a.index('java',2)
# Out:
# 6

# %%
# List me 2nd index pe “AI” insert karo.
a=['python','java',23,65,87,'php','java','python']
a.insert(2,'AI')
print(a)
# Out:
# ['python', 'java', 'AI', 23, 65, 87, 'php', 'java', 'python']

# %%
# List ka last item .pop() se hatao.
a=['python','java',23,65,87,'php','java','python']
a.pop()
print(a)
# Out:
# ['python', 'java', 23, 65, 87, 'php', 'java']

# %%
# List me “java” ko .remove() se hatao.
a=['python','java',23,65,87,'php','java','python']
a.remove('java')
print(a)
# Out:
# ['python', 23, 65, 87, 'php', 'java', 'python']

# %%
# Ek list ko reverse karo using .reverse().
a=['python','java',23,65,87,'php','java','hello','python']
a.reverse()
print(a)
# Out:
# ['python', 'hello', 'java', 'php', 87, 65, 23, 'java', 'python']

# %%
# Ek list ko sort karo ascending order me.
a=['python','java',23,54,34,'php','java','hello','python']
a=[str(i) for i in a]
a.sort()
print(a)
# Out:
# ['23', '34', '54', 'hello', 'java', 'java', 'php', 'python', 'python']

# %%
# List me se duplicate values hatao.
a=['python','java',23,54,34,'php','java','hello','python']
list(set(a))
# Out:
# ['php', 34, 'java', 'hello', 'python', 54, 23]

# %%
# List ke elements ka type check karo (int, str etc).
a=['python','java',23,54,34,'php','java','hello','python']
c=[type(i) for i in a]
print(c)
# Out:
# [<class 'str'>, <class 'str'>, <class 'int'>, <class 'int'>, <class 'int'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]

# %%
name = '24'
print(isinstance(int(name), int))
# Out:
# True

# %%
# List me se sirf integers ka list banao.
a=['python','java',23,24,34,'php','java','hello','python']
[i for i in a if isinstance(i, int)]
# Out:
# [str, str, int, int, int, str, str, str, str]

# %%
a='5'
if a==int(a):
  print('True')
else:
  print('False')
# Out:
# False

# %%
a=6
print( isinstance(a, int))
# Out:
# True

# %%
a=['python','java',23,24.5,34,'php','java','hello','python']
[i for i in a if isinstance(i, int)]
# Out:
# [23, 34]

# %%
a='5'
isinstance(int(a),int)
# Out:
# True

# %%
a=['python','java',23,[24.5,34],'php',['java'],'hello','python']

# %%
[item for i in a for item in (i if isinstance(i, list) else [i])]
# Out:
# ['python', 'java', 23, 24.5, 34, 'php', 'java', 'hello', 'python']
