# %% [markdown]
# <a href="https://colab.research.google.com/github/gurudattamanpreet/Practice/blob/main/Python_Test_GT_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ek string lo, uska first letter capital karo.
a='python is language'
a=a.capitalize()
print(a)
# Out:
# Python is language

# %%
# Ek string lo, use case-insensitive compare karo kisi dusri string se
s1='python'
s2='java'
s1.islower()==s2.islower()
# Out:
# True

# %%
s1='PYTHON'
s2='python'
s1.casefold()==s2.casefold()
# Out:
# True

# %%
# Ek string lo, use center karo width 20 ke andar "*" se.
a='python'
a.center(20,'*')
# Out:
# '*******python*******'

# %%
# Ek string me "python" word kitni baar aata hai, count karo.
a='python is programming language, python is compiler & interpreter language'
a.count('python')
# Out:
# 2

# %%
# String ko encode karo 'utf-8' me.
a='python'
b=a.encode('utf-8')
b=b.decode('utf-8')
print(b)
# Out:
# python

# %%
# String check karo 'end' word se khatam hoti hai ya nahi.
a='python is programming language'
a.endswith('end')
# Out:
# False

# %%
# String me \t ho to usse 4 space me convert karo.
b = 'python\tlanguage'
print(b.expandtabs(4))
# Out:
# python  language

# %%
# String me "java" ka position dhoondo
a='which is a java programming language'
a.index('java')
# Out:
# 11

# %%
# "{} is awesome" — isme "Python" insert karo using format.
a='python'
print(f'{a} is awesome')
# Out:
# python is awesome

# %%
# Kisi dict ko use karke format_map lagao string me values daalne ke liye.
# nahi aata

# %%
# "hello world" me 'o' ka index find karo.
a="hello world"
print(a.index('o'))
# Out:
# 4

# %%
# Ek string check karo alphanumeric hai ya nahi.
a='Manpreetalpha95'
print(a.isalnum())
# Out:
# True

# %%
# Ek string check karo sirf alphabets hain ya nahi.
a='Manpreet'
print(a.isalpha())
# Out:
# True

# %%
# String me non-ascii characters check karo.
a='É, à, ö, ñ, 漢'
if not a.isascii():
  print('asci ni h')
# Out:
# asci ni h

# %% [markdown]
# ![Screenshot 2025-04-06 at 22.15.20.png](data:image/png;base64,...)

# %%
# Ek string check karo sari digits decimal hain ya nahi.
a='12355'
print(a.isdecimal())
# Out:
# True

# %%
# Ek string me koi char sirf digit hai ya nahi, check karo.
a='12345'
print(a.isdigit())
# Out:
# True

# %%
# Ek string valid identifier hai ya nahi, check karo.
# nahi aata

# %%
# Ek string lower case me hai ya nahi.
a='python'
print(a.islower())
# Out:
# True

# %%
# Ek string check karo numeric value hi hai ya nahi
a='123'
print(a.isnumeric())
# Out:
# True

# %%
# Ek string printable characters se bana hai ya nahi.
a='python'
print(a.isprintable())
# Out:
# True

# %%
# Ek string sirf spaces se bana hai ya nahi.
a=' '
print(a.isspace())
# Out:
# True

# %%
# Ek string title case me hai ya nahi.
a='Python'
print(a.istitle())
# Out:
# True

# %%
# Ek string upper case me hai ya nahi.
a='PYTHON'
print(a.isupper())
# Out:
# True

# %%
# Ek list of words ko ek string me jodo (space se)
a=['harry', 'met', 'sejal']
a=' '.join(a)
print(a)
# Out:
# harry met sejal

# %%
# Ek string ko left justify karo 20 width me with #
a='harry met sejal'
a.ljust(20,'#')
# Out:
# 'harry met sejal#####'

# %%
# Ek string ko lower case me convert karo.
a='HARRY MET SEJAL'
a=a.lower()
print(a)
# Out:
# harry met sejal

# %%
# Ek string ke left se white space hatao.
a='           harry met sejal'
a=a.lstrip()
print(a)
# Out:
# harry met sejal

# %%
# Ek string se prefix 'un' hatao (removeprefix).
a='unitary@gmail.com'
a.removeprefix('un')
# Out:
# 'itary@gmail.com'

# %%
# Ek string se suffix '.com' hatao (removesuffix).
a='abc@gmail.com'
a.removesuffix('.com')
# Out:
# 'abc@gmail'

# %%
# Ek string me 'python' ko 'java' se replace karo.
a='python is a programming language'
a=a.replace('python','java')
print(a)
# Out:
# java is a programming language

# %%
# Ek empty list banao aur usme "python" add karo.
a=[]
a.insert(0,'php')
print(a)
# Out:
# ['php']

# %%
a=['harry met sejal']
a.clear()
print(a)
# Out:
# []

# %%
# Ek list copy karo aur dono alag objects hone chahiye.
a=['python is a programming language']
b=a.copy()
print(a,id(a))
print(b,id(b))
# Out:
# ['python is a programming language'] 132757671963392
# ['python is a programming language'] 132758158190720

# %%
# Ek list me "python" kitni baar aaya, count karo.
a='python is a programming language, python is interpretor python and compiler language'
a.count('python')
# Out:
# 3

# %%
# Ek list me ek aur list merge karo (extend).
a=['python is a programming language']
b=['harry met sejal']
a.extend(b)
print(a)
# Out:
# ['python is a programming language', 'harry met sejal']

# %%
# Ek list me "java" ka index nikaalo.
a=['python and java are programming language']
a.index('java',1)
# ye string me a.index kaam kr rha tha lekin list me a.index nahi kaam kr rha h

# %%
# Ek list me 2nd position pe "AI" insert karo.
a=['python and java are programming language']
a.insert('AI',3)
print(a)
# list me insert krna bhi nhi aa rha h, value aur uske baad uska index diya pr error aa rha h

# %%
# Ek list ka last item hatao (pop).
a=['python and java are programming language']
a.pop(-1)
# ye bhi nahi aaya mujhe
# Out:
# 'python and java are programming language'

# %%
# Ek list me "java" remove karo.
a=['python and java are programming language']
a.remove('java')
print(a)
# ye bhi nahi aaya mujhe

# %%
# Ek list ko reverse order me karo.
a=['python and java are programming language']
a.sort(reverse=True)
print(a)
# isse reverse order me nhi ho rha h
# maine ye slicing se bhi try kiya a[::-1] isse bhi nhi ho rha h
# Out:
# ['python and java are programming language']

# %%
# Ek list ko ascending order me sort karo.
a=[23,45,65,34,76,98]
a.sort()
print(a)
# Out:
# [23, 34, 45, 65, 76, 98]

# %%
# Ek empty set banao, usme 3 items add karo.
a={'harry','met','sejal'}
a.update({'rehan'})
print(a)
# ye nahi aata mujhe
# Out:
# {'harry', 'sejal', 'met', 'rehan'}

# %%
# Ek set clear karo.
a={'harry','met','sejal'}
a.clear()
print(a)
# Out:
# set()

# %%
# Ek set ko copy karo.
a={'harry','met','sejal'}
b=a.copy()
print(b)
# Out:
# {'harry', 'sejal', 'met'}

# %%
# Do set ka difference nikaalo.
a={23,54,65,54,43}
b={54,76,54,32,76}
print(b-a)
# ye mujhe smjh nhi aaya
# Out:
# {32, 76}

# %%
# Do set ka intersection nikaalo.
a={23,54,65,54,43}
b={54,76,54,32,76,23}
a.intersection(b)
# Out:
# {23, 54}

# %%
# Ek item ko safely discard karo (chahe ho ya na ho).
# ye nahi aata mujhe

# %%
# Set1 aur Set2 disjoint hai ya nahi, check karo.
# nahi aata mujhe

# %%
# Ek set subset hai ya nahi, check karo.
# nahi aata mujhe

# %%
# Ek set superset hai ya nahi, check karo.
# Set ka pop use karo, aur dekho kya return karta hai.
# Do set ka symmetric difference nikaalo.
# Set1 ko Set2 ke symmetric difference se update karo.
# Do set ka union banao.
# Set1 me Set2 ko add karo (update).

# ye saare mujhe nahi aate

# %%
# Ek dict banao aur clear karo.
a={'name:'['name','age','grade'],'values:'['fde',23,'A']}
print(a)
# mujhe dictionary banana aati thi lekin bhool gya practice nhi hui

# %%
# Ek dict ka copy banao.
# 58. Ek list of keys ko default values ke saath dict me convert karo
# using fromkeys.
# 59. Kisi key ka value safely get karo, agar nahi hai to None aaye.
# 60. Dict ke items print karo (key-value pairs).
# 61. Dict ke keys aur values print karo.
# 62. Dict se koi item (key) pop karo.
# 63. Dict se last item pop karo (popitem).
# 64. setdefault() se koi key add karo jo pehle nahi thi.
# 65. Do dicts ko merge karo using update.
# 66. Dict ki values ka list print karo.
# ⸻
# 📝 BONUS: Weakness Targeted (Tere Previous Attempts Se)
# 67. Ek list me se duplicate elements remove karo (mixed type list
# ho).
# 68. Ek string me uppercase letters count karo.
# 69. Ek sentence ka longest word nikaalo.
# 70. Ek sentence ke words ko reverse order me print karo.
# 71. Ek string me se vowels hatao (bina function ke, min lines me).
# 72. 73. 74. 75. Do list me se common elements print karo (set use karke).
# Ek nested list ko flatten karo (2 level tak) bina recursion.
# Do dictionaries merge karo, aur common key ki value update ho.
# Ek string me unique words count karo (ignore case).

# mujhe ye sab nahi aa rhe h, please isme bhi help krdo meri
