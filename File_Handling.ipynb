# %% [markdown]
# <a href="https://colab.research.google.com/github/gurudattamanpreet/Practice/blob/main/File_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('mydata.txt','w') as f:
  lines=f.write('python is awesome')
  print(lines)
# Out:
# 17

# %%
f=open('mydata.txt','r')
f.read()
# Out:
# 'python is awesome'

# %%
lines=['python\n','is\n','awesome\n']
with open('mydata.txt','w') as f:
    f.writelines(lines)

# %%
with open('mydata.txt','r') as f:
  for i in f:
    print(i.strip())
# Out:
# python
# is
# awesome

# %%
s1=['java\n','&\n','python\n','both\n', 'are\n', 'programming\n', 'languages\n']
with open('mydata.txt','w') as f:
  f.writelines(s1)

# %%
f=open('mydata.txt','r')
f.read()
# Out:
# 'java\n&\npython\nboth\nare\nprogramming\nlanguages\n'

# %%
with open('mydata.txt','r') as f:
  for i in f:
    print(i.strip())
# Out:
# java
# &
# python
# both
# are
# programming
# languages

# %%
Line 1: Python is great
Line 2: I love learning
Line 3: Let's master file handling
Line 4: Practice makes perfect

# %%
s2=['Python is great\n','I love learning\n',"Let's master file handling\n",'Practice makes perfect\n']
with open('mydata.txt','w') as f:
  f.writelines(s2)

# %%
with open('mydata.txt','r') as f:
  for i in f:
    print(i.strip())
# Out:
# Python is great
# I love learning
# Let's master file handling
# Practice makes perfect

# %%
Tasks:

1.	Line 2 ke baad ye line add karo: "I am getting better!"
	2.	Line 3 ko "Let's master file handling in Python" se replace karo
	3.	Last second line (Line 3) ko delete karo
	4.	Line 1 ke aage "--- Start of File ---" daalo
	5.	Poore file ka uppercase version print karo

# %%
with open("mydata.txt", "r") as f:
    lines = f.readlines()

# index 2 after line 2

lines.insert(2,'I am getting better\n')

with open('mydata.txt','w') as f:
  f.writelines(lines)

# %%
with open('mydata.txt','r') as f:
  for i in f:
    print(i.strip())
# Out:
# Python is great
# I love learning
# I am getting better
# Let's master file handling
# Practice makes perfect

# %%
with open('mydata.txt','r') as f:
  lines=f.readlines()
lines[2]="Let's master file handling in Python\n"
with open('mydata.txt','w') as f:
  f.writelines(lines)

# %%
with open('mydata.txt','r') as f:
  for i in f:
    print(i.strip())
# Out:
# Python is great
# I love learning
# Let's master file handling in Python
# Let's master file handling
# Practice makes perfect

# %%
with open('mydata.txt','r') as f:
  lines=f.readlines()

lines.pop(2)
with open('mydata.txt','w') as f:
  f.writelines(lines)

# %%
with open('mydata.txt','r') as f:
  for i in f:
    print(i.strip())
# Out:
# Python is great
# I love learning
# Let's master file handling
# Practice makes perfect

# %%
with open('mydata.txt','r') as f:
  lines=f.readlines()

lines.insert(0,'--- Start of File ---')

# lines[0] = lines[0].replace('python', 'python java')

with open('mydata.txt','w') as f:
  f.writelines(lines)

# %%
with open('mydata.txt','r') as f:
  print(f.read())
  # for i in f:
  #   print(i.strip())
# Out:
# --- Start of File ---Python is great
# I love learning
# Let's master file handling
# Practice makes perfect

# %%
line=['python is awesome\n','it is a great language\n']
with open('mydata2.txt','w') as f:
  f.writelines(line)

# %%
with open('mydata2.txt','r') as f:
  print(f.read())
# Out:
# python is awesome
# it is a great language

# %%
# 1.	Line 2 ko "Java is also amazing" se replace karo
# 	2.	Last line delete karo
# 	3.	Top pe "--- Modified File ---" add karo
with open('mydata2.txt','r') as f:
  print(f.read())
# Out:
# python is awesome
# it is a great language

# %%
with open('mydata2.txt','w') as f:
  line[1]='java is also amazing\n'
with open('mydata2.txt','w') as f:
  f.writelines(line)

# %%
with open('mydata2.txt','r') as f:
  print(f.read())
# Out:
# python is awesome
# java is also amazing
