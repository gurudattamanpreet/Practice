# %% [markdown]
# <a href="https://colab.research.google.com/github/gurudattamanpreet/Practice/blob/main/exception_handeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  a=int(input('enter 1st number: '))
  b=int(input('enter 2nd number: '))
  print(a+b)
  print(a/b)
except ValueError:
  print('int dena h value nhi')
except ZeroDivisionError:
  print('zero se divide nhi kr skta')
else:
  print('nothing')
finally:
  print('har haal me chalega')
# Out:
# enter 1st number: 5
# enter 2nd number: 0
# 5
# zero se divide nhi kr skta
# har haal me chalega

# %%
# try:
#     # Yeh risky code hota hai
#     pass
# except SomeError:
#     # Agar error aayi toh yeh chalega
#     pass
# else:
#     # Agar error nahi aayi toh yeh chalega
#     pass
# finally:
#     # Chahe error aaye ya na aaye, yeh hamesha chalega
#     pass

# %%
try:
  age = int(input("Apni age batao: "))
  if age <18:
    raise
except:
  print('not eligible for vote')
# Out:
# Apni age batao: 5
# not eligible for vote

# %%
try:
    age = int(input("apni age batao: "))

    if age < 0:
        raise ValueError("age negative nhi ho skti")

    if age < 18:
        raise ValueError("voting ke liye 18 saal ka hona zaroori hai.")

    else:
      print("aap vote dene ke liye eligible ho.")

except ValueError as e:
    print(e)
# Out:
# apni age batao: 5
# voting ke liye 18 saal ka hona zaroori hai.
# shesh raashi:5007

# %%
# age = -5

# if age < 0:
#     raise ValueError("age can't be negative!")
#     print('''yeh kabhi execute nahi hoga isliye except ki need h
#           raise seedha except pe jump maarta h''')

# %%
try:
  a=int(input('enter your age: '))

  if a<0:
    raise ValueError("age can't be negative")
  if a<18:
    raise ValueError("not eligible to vote")
  else:
    print('vote dene jaa skte h')
except ValueError as d:
  print(d)
# Out:
# enter your age: 19
# vote dene jaa skte h

# %%
try:
  bal=5000
  a=int(input("enter amount to transfer: "))
  b=int(input("enter party's account number: "))
  if a>bal:
    raise Exception('khate me paryapt dhan ni h')
  if a<0:
    raise Exception('negative amount transfer ni hota bhai')
  if a<=bal:
    b=bal-a
    bal-=a
    print('amount bhej diya gaya h')
    print(f'shesh raashi: {bal}')
except Exception as s:
  print(s)
finally:
  print(f'''Thanks for using this app
remaining balance: {bal}''')
# Out:
# enter amount to transfer: t
# invalid literal for int() with base 10: 't'
# Thanks for using this app
# remaining balance: 5000
