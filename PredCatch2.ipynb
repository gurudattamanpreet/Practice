# %% [markdown]
# <a href="https://colab.research.google.com/github/gurudattamanpreet/Practice/blob/main/PredCatch2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split

# %%
import gdown
url = 'https://drive.google.com/uc?id=1DCvwhFPMfKJUN3Rg3HMj9DoYgz3mIgWC'
output = 'finance_data.zip'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1DCvwhFPMfKJUN3Rg3HMj9DoYgz3mIgWC
# From (redirected): https://drive.google.com/uc?id=1DCvwhFPMfKJUN3Rg3HMj9DoYgz3mIgWC&confirm=t&uuid=828b3a3e-2c89-4957-a00d-82f37bdd715d
# To: /Users/manpreetsingh/Downloads/finance_data.zip
# 100%|██████████████████████████████████████| 40.0M/40.0M [00:07<00:00, 5.10MB/s]
# 'finance_data.zip'

# %%
import zipfile

with zipfile.ZipFile("finance_data.zip", 'r') as zip_ref:
    zip_ref.extractall("finance_data")

# %%
import os
import pandas as pd

# Step 1: Recursively find all CSVs
csv_files = []
for root, dirs, files in os.walk("finance_data"):
    for file in files:
        if file.endswith(".csv"):
            full_path = os.path.join(root, file)
            csv_files.append(full_path)

# Step 2: Sort files for consistent naming
csv_files.sort()

# Step 3: Load into df1, df2, ..., df6
for i, path in enumerate(csv_files, start=1):
    globals()[f'df{i}'] = pd.read_csv(path)
    print(f"✅ Loaded {path} → df{i}")
# Out:
# ✅ Loaded finance_data/Capston project finance dept/Geo_scores.csv → df1
# ✅ Loaded finance_data/Capston project finance dept/Lambda_wts.csv → df2
# ✅ Loaded finance_data/Capston project finance dept/Qset_tats.csv → df3
# ✅ Loaded finance_data/Capston project finance dept/instance_scores.csv → df4
# ✅ Loaded finance_data/Capston project finance dept/test_share.csv → df5
# ✅ Loaded finance_data/Capston project finance dept/train.csv → df6

# %%
w=[df1,df2,df3,df4,df5,df6]
for i in w:
  print(i.shape,'\n')
# Out:
# (1424035, 2)
#
# (1400, 2)
#
# (1424035, 2)
#
# (1424035, 2)
#
# (56962, 27)
#
# (227845, 28)

# %%
s=[df1,df2,df3,df4]
for i in s:
  print(i.columns.tolist())
# Out:
# ['id', 'geo_score']
# ['Group', 'lambda_wt']
# ['id', 'qsets_normalized_tat']
# ['id', 'instance_scores']

# %%
merged1 = pd.merge(df1, df3, on='id', how='left')
merged = pd.merge(merged1, df4, on='id', how='left')

# %%
merged.shape
# Out:
# (35600875, 4)

# %%
merged.columns.tolist()
# Out:
# ['id', 'geo_score', 'qsets_normalized_tat', 'instance_scores']

# %%
s0=[df1,df3,df4]
for i in s0:
  print(i.nunique(),'\n')
# Out:
# id           284807
# geo_score     27155
# dtype: int64
#
# id                      284807
# qsets_normalized_tat     26399
# dtype: int64
#
# id                 284807
# instance_scores     11547
# dtype: int64

# %%
s1=[df1,df3,df4]
for i in s1:
  print(i.duplicated(subset='id').sum(),'\n')
# Out:
# 1139228
#
# 1139228
#
# 1139228

# %%
s2 = [df1, df3, df4]
for x, df in enumerate(s2):
    s2[x] = df.drop_duplicates(subset='id')
df1, df3, df4 = s2

# %%
s3=[df1,df3,df4]
for i in s3:
  print(i.shape,'\n')
# Out:
# (284807, 2)
#
# (284807, 2)
#
# (284807, 2)

# %%
df0=pd.merge(df1,df3,on='id')
merged=pd.merge(df0,df4, on='id')

# %%
merged.shape
# Out:
# (284807, 4)

# %%
df5.shape
# Out:
# (56962, 27)

# %%
df6.shape
# Out:
# (227845, 28)

# %%
df2.nunique()
# Out:
# Group        1400
# lambda_wt    1400
# dtype: int64

# %%
df5.shape
# Out:
# (56962, 27)

# %%
df6.shape
# Out:
# (227845, 28)

# %%
df6.columns
# Out:
# Index(['id', 'Group', 'Per1', 'Per2', 'Per3', 'Per4', 'Per5', 'Per6', 'Per7',
#        'Per8', 'Per9', 'Dem1', 'Dem2', 'Dem3', 'Dem4', 'Dem5', 'Dem6', 'Dem7',
#        'Dem8', 'Dem9', 'Cred1', 'Cred2', 'Cred3', 'Cred4', 'Cred5', 'Cred6',
#        'Normalised_FNT', 'Target'],
#       dtype='object')

# %%
df6['Target'].value_counts()
# Out:
# Target
# 0    227451
# 1       394
# Name: count, dtype: int64

# %%
df5.columns
# Out:
# Index(['id', 'Group', 'Per1', 'Per2', 'Per3', 'Per4', 'Per5', 'Per6', 'Per7',
#        'Per8', 'Per9', 'Dem1', 'Dem2', 'Dem3', 'Dem4', 'Dem5', 'Dem6', 'Dem7',
#        'Dem8', 'Dem9', 'Cred1', 'Cred2', 'Cred3', 'Cred4', 'Cred5', 'Cred6',
#        'Normalised_FNT'],
#       dtype='object')

# %%
merged.columns
# Out:
# Index(['id', 'geo_score', 'qsets_normalized_tat', 'instance_scores'], dtype='object')

# %%
merged.shape
# Out:
# (284807, 4)

# %%
df5.shape
# Out:
# (56962, 27)

# %%
df2.columns
# Out:
# Index(['Group', 'lambda_wt'], dtype='object')

# %%
df7,df8=train_test_split(merged,test_size=0.2,random_state=1)

# %%
df6.shape
# Out:
# (227845, 28)

# %%
df7.shape
# Out:
# (227845, 4)

# %%
train1=pd.merge(df6,df7, on='id',how='left')
test1=pd.merge(df5,df8, on='id',how='left')

# %%
train1.shape
# Out:
# (227845, 31)

# %%
test1.shape
# Out:
# (56962, 30)

# %%
df9,df10=train_test_split(df2,test_size=0.2,random_state=1)

# %%
df9.shape
# Out:
# (1120, 2)

# %%
df9.nunique()
# Out:
# Group        1120
# lambda_wt    1120
# dtype: int64

# %%
df10.shape
# Out:
# (280, 2)

# %%
train_data=pd.merge(train1,df9,on='Group',how='left')
test_data=pd.merge(test1,df10,on='Group',how='left')

# %%
train_data.shape
# Out:
# (227845, 32)

# %%
test_data.shape
# Out:
# (56962, 31)

# %%
train_data.corr(numeric_only=True)['Target'].sort_values(ascending=False)
# Out:
# Target                  1.000000
# Dem1                    0.150343
# Per4                    0.133657
# Per2                    0.093530
# Dem6                    0.034915
# Per8                    0.028638
# Dem8                    0.026403
# Dem7                    0.024294
# Cred5                   0.011801
# Cred6                   0.011039
# Normalised_FNT          0.005469
# Cred3                   0.004814
# Dem9                    0.004088
# Cred4                   0.003521
# Cred1                  -0.003342
# Dem2                   -0.004235
# Dem3                   -0.004541
# Cred2                  -0.006884
# id                     -0.012034
# qsets_normalized_tat   -0.032087
# geo_score              -0.038291
# Per6                   -0.044604
# instance_scores        -0.081047
# Per5                   -0.099358
# Per9                   -0.099559
# Per1                   -0.103576
# Dem5                   -0.112257
# Per7                   -0.187741
# ...

# %%
train_data.nunique()
# Out:
# id                      227845
# Group                     1301
# Per1                      1778
# Per2                      2319
# Per3                      1469
# Per4                      1292
# Per5                      1881
# Per6                      1477
# Per7                      1901
# Per8                      2047
# Per9                      1203
# Dem1                       910
# Dem2                       762
# Dem3                       747
# Dem4                       983
# Dem5                       838
# Dem6                       817
# Dem7                      1505
# Dem8                      1537
# Dem9                       812
# Cred1                     1307
# Cred2                      494
# Cred3                      636
# Cred4                      460
# Cred5                      920
# Cred6                      778
# Normalised_FNT           29299
# Target                       2
# geo_score                13896
# qsets_normalized_tat     13554
# ...

# %%
train_data.describe().T
# Out:
#                          count           mean           std         min  \
# id                    227845.0  142404.076201  82170.248170    0.000000
# Per1                  227845.0       0.666006      0.654133  -18.136667
# Per2                  227845.0       0.667701      0.548305  -23.573333
# Per3                  227845.0       0.666315      0.506357  -15.443333
# Per4                  227845.0       0.666687      0.471956   -1.226667
# Per5                  227845.0       0.666723      0.461393  -37.246667
# Per6                  227845.0       0.667378      0.444573   -8.053333
# Per7                  227845.0       0.666934      0.415657  -13.853333
# Per8                  227845.0       0.666279      0.401546  -23.740000
# Per9                  227845.0       0.666688      0.366537   -3.810000
# Dem1                  227845.0       0.666576      0.340436   -0.893333
# Dem2                  227845.0       0.666329      0.332016   -1.263333
# ...

# %% [markdown]
#     In this we have target column which is only in the train_data
#     the test data donot have any target column because that will be used at the time of deployment
#     hence, we will split the train data into train and validation data so that we can check our model is working fine

# %%
train_data.drop(['id'],axis=1,inplace=True)
test_data.drop(['id'],axis=1,inplace=True)

# %%
X=train_data.drop(['Target'],axis=1)
y=train_data['Target']

# %%
X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.2,random_state=1,stratify=y)

# %%
X_train.shape
# Out:
# (182276, 30)

# %%
X_train.columns
# Out:
# Index(['Group', 'Per1', 'Per2', 'Per3', 'Per4', 'Per5', 'Per6', 'Per7', 'Per8',
#        'Per9', 'Dem1', 'Dem2', 'Dem3', 'Dem4', 'Dem5', 'Dem6', 'Dem7', 'Dem8',
#        'Dem9', 'Cred1', 'Cred2', 'Cred3', 'Cred4', 'Cred5', 'Cred6',
#        'Normalised_FNT', 'geo_score', 'qsets_normalized_tat',
#        'instance_scores', 'lambda_wt'],
#       dtype='object')

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.pipeline import Pipeline as Skpipeline
from imblearn.pipeline import Pipeline as Imbpipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA
from sklearn.ensemble import StackingClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold

# %% [markdown]
#     2. MLOps & Production Perspective
#     Manual Approach Problems: smote outside pipeline
#
#     ❌ Multiple steps to manage
#     ❌ Data leakage risk
#     ❌ Hard to deploy
#     ❌ Difficult to version control
#     ❌ Error-prone in production
#
#     Pipeline Approach Benefits: smote inside pipeline
#     Industry Approach:
#
#     ✅ Single object to deploy
#     ✅ No data leakage (automatic train/test split handling)
#     ✅ Easy to serialize (joblib.dump)
#     ✅ Reproducible
#     ✅ CI/CD friendly

# %%
num_cols = X_train.select_dtypes('number').columns.tolist()
cat_cols = X_train.select_dtypes('object').columns.tolist()

num_pipeline = Skpipeline([
    ('impute', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

cat_pipeline = Skpipeline([
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('encode', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
])

preprocessor = ColumnTransformer([
    ('num', num_pipeline, num_cols),
    ('cat', cat_pipeline, cat_cols)
], remainder='passthrough')

base_model=[
    ('rf',RandomForestClassifier()),
    ('gb',GradientBoostingClassifier()),
    ('svc',SVC()),
    ('knn',KNeighborsClassifier())]

final_model=LogisticRegression(penalty='l2', max_iter=1000)

stack_model=StackingClassifier(
    estimators=base_model,
    final_estimator=final_model,
    cv=5,
    passthrough=False)

# %%
pipe=Imbpipeline([
    ('preprocessor',preprocessor),
    ('pca',PCA(n_components=10)),
    ('smote',SMOTE(sampling_strategy=0.1)),
    ('model',stack_model)])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Per1', 'Per2', 'Per3',
#                                                    'Per4', 'Per5', 'Per6',
#                                                    'Per7', 'Per8', 'Per9',
#                                                    'Dem1', 'Dem2', 'Dem3',
#                                                    'Dem4', 'Dem5', 'Dem6',
#                                                    'Dem7', 'Dem8', 'Dem9',
# ...

# %%
y_test_pred = pipe.predict(X_val)
print(classification_report(y_val, y_test_pred))
# Out:
# /Users/manpreetsingh/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     45490
#            1       0.65      0.72      0.68        79
#
#     accuracy                           1.00     45569
#    macro avg       0.82      0.86      0.84     45569
# weighted avg       1.00      1.00      1.00     45569

# %%
accuracy_score(y_val,y_test_pred)
# Out:
# 0.9988369286137506

# %%
# cv_scores=cross_val_score(pipe, X_train, y_train,
#                            cv=StratifiedKFold(n_splits=5),
#                            scoring='accuracy')

# %%
# print(f"CV Mean: {cv_scores.mean():.3f}")
# print(f"CV Std: {cv_scores.std():.3f}")  # High std = overfitting sign

# %% [markdown]
#     pipe.fit(X_train,y_train) se hamara model trained ho gya with SMOTE
#
#     ab is balanced model jo train hua h uska effect test data pr kaisa aa rha h hum ye dekhte h
#     ab humko iska direct effect validatation/test data pe dekhna hota h

# %%
# X_full = train_data.drop('Target', axis=1)
# y_full = train_data['Target']

# pipe.fit(X_full, y_full)  # final training

# %%
# # Step 1: Predict on test_data
# y_test_pred = pipe.predict(test_data)

# # Step 2: Create a copy of test_data to preserve original
# submission = test_data.copy()

# # Step 3: Add prediction column at the end
# submission['prediction'] = y_test_pred

# # Step 4: Save to CSV
# submission.to_csv('submission.csv', index=False)
