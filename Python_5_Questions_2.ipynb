# %% [markdown]
# <a href="https://colab.research.google.com/github/gurudattamanpreet/Practice/blob/main/Python_5_Questions_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Q1 Check that Strings are anagrams of each other, for example Army and Mary are an anagram
# Q2 How to find all permutations of String? example if user input "xyz" the n "zxy","xzy","yzx","zyx" are permutations?
# Q3 How to find the largest palllindrom string in paragraphs
# Q4 How to find common elements in three sorted array, arral={1,5,7}, array2={1,5,2,3,9},array3 = {3,9,1,11} output 1
# Q5 WAP to display binary data of each array elements?

# %%
# Q1 Check that Strings are anagrams of each other, for example Army and Mary are an anagram
a=input('enter 1st word: ')
b=input('enter 2nd word: ')
if sorted(a.lower())==sorted(b.lower()):
  print('anagram')
else:
  print('nhi h')
# Out:
# enter 1st word: lary
# enter 2nd word: mary
# nhi h

# %%
# Q3 How to find the largest palllindrom string in paragraphs
a='madam noon naan programming'
max([x for x in a.split() if x==x[::-1]], key=len)
# Out:
# 'madam'

# %%
# Q4 How to find common elements in three sorted array, arral={1,5,7}, array2={1,5,2,3,9},array3 = {3,9,1,11} output 1
a={1,5,7}
b={1,5,2,3,9}
c={3,9,1,11}
a.intersection(b,c)
# Out:
# {1}

# %%
# Q5 WAP to display binary data of each array elements?
# a=5
# ord('a')  >> this is to find ascii value
# bin(ord('a')) >> this is find bianry number

a={1,5,2,3,9}
for i in a:
  print(f'{i} = {bin(i)}')
# Out:
# 1 = 0b1
# 2 = 0b10
# 3 = 0b11
# 5 = 0b101
# 9 = 0b1001
